# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Import libraries
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Pooled OLS
import statsmodels.api as sm
from linearmodels.panel import PooledOLS
# FE  model
from linearmodels import PanelOLS
from sklearn.impute import KNNImputer

# %%
# Create your connection.
con = sqlite3.connect('indicators.sqlite3')

# %%
climate_data = pd.read_sql_query("SELECT * FROM climate_indicators", con)
economic_data = pd.read_sql_query("SELECT * FROM econ_indicators", con)
region_mapping = pd.read_sql_query("SELECT * FROM region_mapping", con)

# %% [markdown]
# ### Exploring climate data

# %%
#print the head of the data frame.
climate_data.head()
# Out:
#   country iso_code  year  co2_emissions_kt  co2_emissions_capita  forest_area  \
# 0   Aruba      ABW  1995               NaN                   NaN     2.333333
# 1   Aruba      ABW  1996               NaN                   NaN     2.333333
# 2   Aruba      ABW  1997               NaN                   NaN     2.333333
# 3   Aruba      ABW  1998               NaN                   NaN     2.333333
# 4   Aruba      ABW  1999               NaN                   NaN     2.333333
#
#    population  electricity_pro_hydro  electricity_pro_natural_gas  \
# 0     80324.0                    NaN                          NaN
# 1     83211.0                    NaN                          NaN
# 2     85450.0                    NaN                          NaN
# 3     87280.0                    NaN                          NaN
# 4     89009.0                    NaN                          NaN
#
#    electricity_pro_nuclear  electricity_pro_oil  electricity_pro_coal  \
# 0                      NaN                  NaN                   NaN
# 1                      NaN                  NaN                   NaN
# 2                      NaN                  NaN                   NaN
# 3                      NaN                  NaN                   NaN
# 4                      NaN                  NaN                   NaN
#
#    electricity_pro_fossils  electricity_pro_renewable  pm_25  sf6_emissions  \
# 0                      NaN                        NaN    NaN            NaN
# 1                      NaN                        NaN    NaN            NaN
# 2                      NaN                        NaN    NaN            NaN
# 3                      NaN                        NaN    NaN            NaN
# 4                      NaN                        NaN    NaN            NaN
#
#    ghg_total  ghg_growth  ghg_capita  mean_surface_temp
# 0        NaN         NaN         NaN              0.573
# 1        NaN         NaN         NaN              0.727
# 2        NaN         NaN         NaN                NaN
# 3        NaN         NaN         NaN                NaN
# 4        NaN         NaN         NaN                NaN

# %%
climate_data.tail()
# Out:
#        country iso_code  year  co2_emissions_kt  co2_emissions_capita  \
# 5245  Zimbabwe      ZWE  2015           12400.0              0.897598
# 5246  Zimbabwe      ZWE  2016           10990.0              0.783303
# 5247  Zimbabwe      ZWE  2017           10230.0              0.718570
# 5248  Zimbabwe      ZWE  2018           12270.0              0.849793
# 5249  Zimbabwe      ZWE  2019               NaN                   NaN
#
#       forest_area  population  electricity_pro_hydro  \
# 5245    45.689363  13814642.0              51.395612
# 5246    45.570273  14030338.0                    NaN
# 5247    45.451183  14236599.0                    NaN
# 5248    45.332093  14438812.0                    NaN
# 5249    45.213002  14645473.0                    NaN
#
#       electricity_pro_natural_gas  electricity_pro_nuclear  \
# 5245                          0.0                      NaN
# 5246                          NaN                      NaN
# 5247                          NaN                      NaN
# 5248                          NaN                      NaN
# 5249                          NaN                      NaN
#
#       electricity_pro_oil  electricity_pro_coal  electricity_pro_fossils  \
# 5245             0.494387             46.781337                47.275724
# 5246                  NaN                   NaN                      NaN
# 5247                  NaN                   NaN                      NaN
# 5248                  NaN                   NaN                      NaN
# 5249                  NaN                   NaN                      NaN
#
#       electricity_pro_renewable      pm_25  sf6_emissions  ghg_total  \
# 5245                   1.328664  21.733709            NaN    31280.0
# 5246                        NaN  21.726947            NaN    29120.0
# 5247                        NaN  22.251671            NaN    28800.0
# 5248                        NaN        NaN            NaN    31380.0
# 5249                        NaN        NaN            NaN        NaN
#
#       ghg_growth  ghg_capita  mean_surface_temp
# 5245        5.03        3.10              1.226
# 5246      171.67        8.30              1.470
# 5247       -0.37        8.15              0.443
# 5248        2.31        8.23              0.747
# 5249         NaN         NaN              1.359

# %%
climate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      5250 non-null   object
#  1   iso_code                     5250 non-null   object
#  2   year                         5250 non-null   int64
#  3   co2_emissions_kt             4584 non-null   float64
#  4   co2_emissions_capita         4584 non-null   float64
#  5   forest_area                  5134 non-null   float64
#  6   population                   5217 non-null   float64
#  7   electricity_pro_hydro        2903 non-null   float64
#  8   electricity_pro_natural_gas  2903 non-null   float64
#  9   electricity_pro_nuclear      2798 non-null   float64
#  10  electricity_pro_oil          2903 non-null   float64
#  11  electricity_pro_coal         2903 non-null   float64
#  12  electricity_pro_fossils      2903 non-null   float64
#  13  electricity_pro_renewable    2903 non-null   float64
#  14  pm_25                        2101 non-null   float64
#  15  sf6_emissions                538 non-null    float64
#  16  ghg_total                    4584 non-null   float64
#  17  ghg_growth                   4560 non-null   float64
#  18  ghg_capita                   4553 non-null   float64
#  19  mean_surface_temp            5034 non-null   float64
# dtypes: float64(17), int64(1), object(2)
# memory usage: 820.4+ KB

# %%
climate_data.shape
# Out:
# (5250, 20)

# %%
#checking unique values for categorical variable
climate_data["iso_code"].nunique()
# Out:
# 210

# %% [markdown]
# ### Missing values analysis

# %%
percent_missing = climate_data.isnull().sum() * 100 / len(climate_data)
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df
# Out:
#                              percent_missing
# country                             0.000000
# iso_code                            0.000000
# year                                0.000000
# co2_emissions_kt                   12.685714
# co2_emissions_capita               12.685714
# forest_area                         2.209524
# population                          0.628571
# electricity_pro_hydro              44.704762
# electricity_pro_natural_gas        44.704762
# electricity_pro_nuclear            46.704762
# electricity_pro_oil                44.704762
# electricity_pro_coal               44.704762
# electricity_pro_fossils            44.704762
# electricity_pro_renewable          44.704762
# pm_25                              59.980952
# sf6_emissions                      89.752381
# ghg_total                          12.685714
# ghg_growth                         13.142857
# ghg_capita                         13.276190
# mean_surface_temp                   4.114286

# %% [markdown]
# As electricity production variables, pm25 and sf6 emissions have more almost 50%
# of data missing, we can drop these variables. We drop variables with more than
# 35% of data.

# %%
perc = 35.0
min_count =  int(((100-perc)/100)*climate_data.shape[0] + 1)
climate_data = climate_data.dropna(axis = 1, thresh = min_count)
climate_data.columns
# Out:
# Index(['country', 'iso_code', 'year', 'co2_emissions_kt',
#        'co2_emissions_capita', 'forest_area', 'population', 'ghg_total',
#        'ghg_growth', 'ghg_capita', 'mean_surface_temp'],
#       dtype='object')

# %%
def missing_values_graph(frame, obs, time, var, Yname):
    test = frame[[obs, time, var]]
    test[var].fillna(-1, inplace=True)
    test = test.groupby([obs, time])[var].aggregate('mean').unstack()
    test[test > 0] = 1
    cmap = sns.xkcd_palette(["grey", "blue"])
    plt.figure(figsize=(10, 5))
    ax = sns.heatmap(test, center=0, cmap=cmap, cbar=False,
                     cbar_kws={'ticks': [-1, 0, 1]})
    ax.set(yticklabels=[])
    plt.ylabel(Yname+ " (N=" + str(len(test)) + ")", fontsize=14)
    plt.xlabel("")
    plt.title((var + "\nmissing values (grey), availabe values (blue)"),
              fontsize=14)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# The above function creates a graph for the variable of interest. On the y-axsis you see the the observations (names in this case). On the x-axis you see the years. Available values are highlighed blue, while missing data are grey.

# %%
for col in climate_data.columns[3:]:
    print(missing_values_graph(climate_data, "iso_code", "year", col, col))
# Out:
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None

# %% [markdown]
# ### Exploring economic data

# %%
economic_data.head()
# Out:
#                country iso_code  year gdp_constant_change gdp_capita  \
# 0          Afghanistan      AFG  1995
# 1              Albania      ALB  1995                 8.9    4582.93
# 2              Algeria      DZA  1995               3.848    8158.72
# 3               Angola      AGO  1995              10.364    3973.12
# 4  Antigua and Barbuda      ATG  1995              -4.359   16127.97
#
#   vol_imports_change vol_exports_change population gdp_current energy_usage  \
# 0
# 1                0.0                         3.188       9.643   417.034843
# 2                2.0              5.733      28.06     204.348   843.041996
# 3             27.968              12.24     14.771      37.582   455.666087
# 4                                            0.067       0.909
#
#      imports_gns    exports_gns
# 0
# 1
# 2  16590532511.0  33084611492.0
# 3
# 4

# %%
economic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5070 entries, 0 to 5069
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              5070 non-null   object
#  1   iso_code             5070 non-null   object
#  2   year                 5070 non-null   int64
#  3   gdp_constant_change  5070 non-null   object
#  4   gdp_capita           5070 non-null   object
#  5   vol_imports_change   5070 non-null   object
#  6   vol_exports_change   5070 non-null   object
#  7   population           5070 non-null   object
#  8   gdp_current          5070 non-null   object
#  9   energy_usage         5070 non-null   object
#  10  imports_gns          5070 non-null   object
#  11  exports_gns          5070 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 475.4+ KB

# %%
# convert string columns to numeric dtype
for col in economic_data.columns[3:]:
    economic_data[col]=pd.to_numeric(economic_data[col])
economic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5070 entries, 0 to 5069
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              5070 non-null   object
#  1   iso_code             5070 non-null   object
#  2   year                 5070 non-null   int64
#  3   gdp_constant_change  4932 non-null   float64
#  4   gdp_capita           4926 non-null   float64
#  5   vol_imports_change   4399 non-null   float64
#  6   vol_exports_change   4425 non-null   float64
#  7   population           4948 non-null   float64
#  8   gdp_current          4957 non-null   float64
#  9   energy_usage         2851 non-null   float64
#  10  imports_gns          3730 non-null   float64
#  11  exports_gns          3730 non-null   float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 475.4+ KB

# %%
percent_missing = economic_data.isnull().sum() * 100 / len(climate_data)
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df
# Out:
#                      percent_missing
# country                     0.000000
# iso_code                    0.000000
# year                        0.000000
# gdp_constant_change         2.628571
# gdp_capita                  2.742857
# vol_imports_change         12.780952
# vol_exports_change         12.285714
# population                  2.323810
# gdp_current                 2.152381
# energy_usage               42.266667
# imports_gns                25.523810
# exports_gns                25.523810

# %%
economic_data.shape
# Out:
# (5070, 12)

# %%
perc = 35.0
min_count =  int(((100-perc)/100)*economic_data.shape[0] + 1)
economic_data = economic_data.dropna(axis = 1, thresh = min_count)
economic_data.shape
# Out:
# (5070, 11)

# %%
s1 = climate_data.iso_code.unique().tolist()
s2 = economic_data.iso_code.unique().tolist()
## countries in economic data that are not in climate data
set(s1).difference(s2)
# Out:
# {'AND',
#  'ASM',
#  'CUB',
#  'CYM',
#  'FRO',
#  'GIB',
#  'GRL',
#  'IMN',
#  'LIE',
#  'MCO',
#  'NCL',
#  'PRK',
#  'PSE',
#  'PYF',
#  'TCA',
#  'VGB',
#  'VIR',
#  'WLD'}

# %%
for col in economic_data.columns[3:]:
    print(missing_values_graph(economic_data, "iso_code", "year", col, col))
# Out:
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None
# <ipython-input-168-b4eabe084a37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[var].fillna(-1, inplace=True)
# None

# %% [markdown]
# # Selecting Countries for Region Specific Analysis

# %% [markdown]
# We want to keep countries for which we have enough data to perform further analysis. We start by looking at the percentage of missing values for each country, and ddrop the countries for which this proportion is greater than 35%.

# %%
combined_data = pd.merge(economic_data, climate_data, on = ["iso_code", "year", "country"], how = "left")
combined_data
# Out:
#                   country iso_code  year  gdp_constant_change  gdp_capita  \
# 0             Afghanistan      AFG  1995                  NaN         NaN
# 1                 Albania      ALB  1995                8.900     4582.93
# 2                 Algeria      DZA  1995                3.848     8158.72
# 3                  Angola      AGO  1995               10.364     3973.12
# 4     Antigua and Barbuda      ATG  1995               -4.359    16127.97
# ...                   ...      ...   ...                  ...         ...
# 5065              Vietnam      VNM  2020                2.906    10302.96
# 5066   West Bank and Gaza      WBG  2020              -10.960     5107.62
# 5067                Yemen      YEM  2020               -5.000     1826.98
# 5068               Zambia      ZMB  2020               -3.497     3167.98
# 5069             Zimbabwe      ZWE  2020               -8.002     2485.31
#
#       vol_imports_change  vol_exports_change  population_x  gdp_current  \
# 0                    NaN                 NaN           NaN          NaN
# 1                  0.000                 NaN         3.188        9.643
# 2                  2.000               5.733        28.060      204.348
# 3                 27.968              12.240        14.771       37.582
# 4                    NaN                 NaN         0.067        0.909
# ...                  ...                 ...           ...          ...
# 5065               2.948               2.822        97.406     1058.690
# 5066             -10.409             -10.977         5.101       27.486
# 5067             -30.204              -6.866        32.471       62.583
# 5068               2.635               1.143        18.882       63.103
# 5069                 NaN                 NaN        15.189       39.824
#
#        imports_gns   exports_gns  co2_emissions_kt  co2_emissions_capita  \
# 0              NaN           NaN            1250.0              0.069020
# 1              NaN           NaN            1950.0              0.611710
# 2     1.659053e+10  3.308461e+10           73050.0              2.540181
# 3              NaN           NaN           10780.0              0.773026
# 4              NaN           NaN             270.0              3.931733
# ...            ...           ...               ...                   ...
# 5065  2.973920e+11  2.951710e+11               NaN                   NaN
# 5066           NaN           NaN               NaN                   NaN
# 5067           NaN           NaN               NaN                   NaN
# 5068           NaN           NaN               NaN                   NaN
# 5069           NaN           NaN               NaN                   NaN
#
#       forest_area  population_y  ghg_total  ghg_growth  ghg_capita  \
# 0        1.850994    18110662.0    13480.0        1.88        0.61
# 1       28.432482     3187784.0     7430.0       -3.06        2.39
# 2        0.681435    28757788.0   103000.0        4.23        3.60
# 3       62.954757    13945205.0    48460.0        6.50        5.12
# 4       22.227273       68672.0      460.0        6.14        6.69
# ...           ...           ...        ...         ...         ...
# 5065          NaN           NaN        NaN         NaN         NaN
# 5066          NaN           NaN        NaN         NaN         NaN
# 5067          NaN           NaN        NaN         NaN         NaN
# 5068          NaN           NaN        NaN         NaN         NaN
# 5069          NaN           NaN        NaN         NaN         NaN
#
#       mean_surface_temp
# 0                 0.401
# 1                -0.127
# 2                 0.619
# 3                 0.827
# 4                 0.522
# ...                 ...
# 5065                NaN
# 5066                NaN
# 5067                NaN
# 5068                NaN
# 5069                NaN
#
# [5070 rows x 19 columns]

# %%
def missing_data_prop(df):
    perc = 35.0
    min_count =  int(((100-perc)/100)*df.shape[0] + 1)
    df = df.dropna(axis = 1, thresh = min_count)
    return df

# %%
drop_countries = []
for country in combined_data["iso_code"].unique():
    df = combined_data[combined_data["iso_code"] == country]
    df_clean = missing_data_prop(df)
    if df.shape[1] != df_clean.shape[1]:
        drop_countries.append(country)

combined_data = combined_data[combined_data.iso_code.isin(drop_countries) == False]

# %%
#114 countries left
combined_data.iso_code.unique()
# Out:
# array(['ALB', 'DZA', 'AGO', 'ARG', 'ARM', 'AUS', 'AUT', 'BHR', 'BGD',
#        'BLR', 'BEL', 'BLZ', 'BEN', 'BTN', 'BOL', 'BIH', 'BWA', 'BRA',
#        'BRN', 'BGR', 'BFA', 'KHM', 'CMR', 'CAN', 'CHL', 'COL', 'COM',
#        'CRI', 'HRV', 'CYP', 'CZE', 'DNK', 'DOM', 'ECU', 'SLV', 'EST',
#        'SWZ', 'FIN', 'FRA', 'GAB', 'DEU', 'GRC', 'GTM', 'HTI', 'HND',
#        'HUN', 'ISL', 'IND', 'IDN', 'IRL', 'ISR', 'ITA', 'JPN', 'JOR',
#        'KAZ', 'KEN', 'KGZ', 'LVA', 'LBN', 'LSO', 'LBY', 'LTU', 'LUX',
#        'MDG', 'MYS', 'MLI', 'MLT', 'MRT', 'MUS', 'MEX', 'MDA', 'MAR',
#        'MOZ', 'NAM', 'NLD', 'NZL', 'NIC', 'NER', 'NGA', 'MKD', 'NOR',
#        'OMN', 'PAK', 'PAN', 'PRY', 'PER', 'PHL', 'POL', 'PRT', 'ROU',
#        'SAU', 'SEN', 'SLE', 'SGP', 'SVK', 'SVN', 'SLB', 'ZAF', 'ESP',
#        'LKA', 'SWE', 'CHE', 'TZA', 'THA', 'TGO', 'TUN', 'TUR', 'UGA',
#        'UKR', 'ARE', 'GBR', 'USA', 'UZB', 'VNM'], dtype=object)

# %% [markdown]
# # Pooled OLS

# %%
#merged climate data and economic data
# data = pd.merge(economic_data, climate_data, on = ["iso_code", "year", "country"], how = "left")
data = combined_data.copy()
data
# Out:
#                    country iso_code  year  gdp_constant_change  gdp_capita  \
# 1                  Albania      ALB  1995                8.900     4582.93
# 2                  Algeria      DZA  1995                3.848     8158.72
# 3                   Angola      AGO  1995               10.364     3973.12
# 5                Argentina      ARG  1995               -2.845    17387.03
# 6                  Armenia      ARM  1995                8.033     3008.39
# ...                    ...      ...   ...                  ...         ...
# 5058  United Arab Emirates      ARE  2020               -5.924    55693.97
# 5059        United Kingdom      GBR  2020               -9.920    41819.88
# 5060         United States      USA  2020               -3.505    60114.17
# 5062            Uzbekistan      UZB  2020                1.648     7061.48
# 5065               Vietnam      VNM  2020                2.906    10302.96
#
#       vol_imports_change  vol_exports_change  population_x  gdp_current  \
# 1                  0.000                 NaN         3.188        9.643
# 2                  2.000               5.733        28.060      204.348
# 3                 27.968              12.240        14.771       37.582
# 5                -11.484              25.559        34.779      347.223
# 6                    NaN                 NaN         3.220        5.862
# ...                  ...                 ...           ...          ...
# 5058             -18.151             -13.652        11.077      650.829
# 5059             -18.127             -16.721        67.093     2959.920
# 5060              -9.285             -12.970       330.086    20932.750
# 5062             -13.564             -17.914        33.906      252.576
# 5065               2.948               2.822        97.406     1058.690
#
#        imports_gns   exports_gns  co2_emissions_kt  co2_emissions_capita  \
# 1              NaN           NaN            1950.0              0.611710
# 2     1.659053e+10  3.308461e+10           73050.0              2.540181
# 3              NaN           NaN           10780.0              0.773026
# 5     2.737656e+10  3.314611e+10          113810.0              3.267757
# 6     2.493916e+09  6.852152e+08            3510.0              1.090960
# ...            ...           ...               ...                   ...
# 5058           NaN           NaN               NaN                   NaN
# 5059  8.073590e+11  8.023020e+11               NaN                   NaN
# 5060  2.839770e+12  2.105430e+12               NaN                   NaN
# 5062  2.251167e+10  1.475860e+10               NaN                   NaN
# 5065  2.973920e+11  2.951710e+11               NaN                   NaN
#
#       forest_area  population_y  ghg_total  ghg_growth  ghg_capita  \
# 1       28.432482     3187784.0     7430.0       -3.06        2.39
# 2        0.681435    28757788.0   103000.0        4.23        3.60
# 3       62.954757    13945205.0    48460.0        6.50        5.12
# 5       12.530100    34828168.0   260580.0        0.19        8.78
# 6       11.720583     3217349.0     6710.0        9.73        2.13
# ...           ...           ...        ...         ...         ...
# 5058          NaN           NaN        NaN         NaN         NaN
# 5059          NaN           NaN        NaN         NaN         NaN
# 5060          NaN           NaN        NaN         NaN         NaN
# 5062          NaN           NaN        NaN         NaN         NaN
# 5065          NaN           NaN        NaN         NaN         NaN
#
#       mean_surface_temp
# 1                -0.127
# 2                 0.619
# 3                 0.827
# 5                 0.210
# 6                 0.730
# ...                 ...
# 5058                NaN
# 5059                NaN
# 5060                NaN
# 5062                NaN
# 5065                NaN
#
# [2964 rows x 19 columns]

# %%
data["log_ghg_capita"] = np.log(data["ghg_capita"])
data["log_gdp_capita"] = np.log(pd.to_numeric(data["gdp_capita"]))
data["log_gdp_capita_sq"] = (np.log(pd.to_numeric(data["gdp_capita"])))**2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data[data["ghg_capita"] < 0]
# Out:
#               country iso_code  year  gdp_constant_change  gdp_capita  \
# 19             Bhutan      BTN  1995                6.019     3345.68
# 214            Bhutan      BTN  1996                5.971     3517.82
# 409            Bhutan      BTN  1997                5.544     3655.84
# 484            Latvia      LVA  1997                8.864    10794.23
# 604            Bhutan      BTN  1998                6.009     3781.16
# 679            Latvia      LVA  1998                6.341    11593.05
# 799            Bhutan      BTN  1999                7.087     3938.49
# 874            Latvia      LVA  1999                2.741    12017.76
# 994            Bhutan      BTN  2000                6.934     4099.58
# 1069           Latvia      LVA  2000                5.672    12792.89
# 1189           Bhutan      BTN  2001                7.040     4259.78
# 1264           Latvia      LVA  2001                6.323    13765.51
# 1384           Bhutan      BTN  2002                9.516     4532.50
# 1459           Latvia      LVA  2002                7.083    14946.44
# 1579           Bhutan      BTN  2003                9.320     4867.31
# 1654           Latvia      LVA  2003                8.434    16359.10
# 1774           Bhutan      BTN  2004                6.876     5110.02
# 1849           Latvia      LVA  2004                8.501    17928.15
# 1969           Bhutan      BTN  2005                6.666     5354.27
# 2044           Latvia      LVA  2005               10.725    20087.40
# 2164           Bhutan      BTN  2006                7.137     5634.98
# 2239           Latvia      LVA  2006               11.986    22715.77
# 2359           Bhutan      BTN  2007               12.861     6282.23
# 2434           Latvia      LVA  2007               10.027    25208.87
# 2554           Bhutan      BTN  2008               10.964     6886.11
# 2629           Latvia      LVA  2008               -3.327    24559.45
# 2749           Bhutan      BTN  2009                5.801     7196.82
# 2824           Latvia      LVA  2009              -14.260    21339.45
# 2944           Bhutan      BTN  2010                9.484     7783.44
# 3019           Latvia      LVA  2010               -4.407    20806.27
# 3261          Romania      ROU  2011                1.906    20857.32
# 3275  Solomon Islands      SLB  2011                7.267     2295.52
# 3456          Romania      ROU  2012                2.041    21392.14
# 3470  Solomon Islands      SLB  2012                1.865     2288.97
# 3651          Romania      ROU  2013                3.771    22282.99
# 3665  Solomon Islands      SLB  2013                5.332     2357.80
# 3846          Romania      ROU  2014                3.609    23164.65
# 3860  Solomon Islands      SLB  2014                1.050     2328.99
# 3958          Finland      FIN  2015                0.544    45145.07
# 4041          Romania      ROU  2015                2.954    23941.97
# 4055  Solomon Islands      SLB  2015                1.417     2311.15
#
#       vol_imports_change  vol_exports_change  population_x  gdp_current  \
# 19                 1.457               8.732         0.503        1.014
# 214                9.964              18.539         0.507        1.094
# 409               15.277              -0.656         0.515        1.174
# 484                8.964              13.493         2.445       17.454
# 604               30.857              -4.299         0.528        1.259
# 679               20.357               8.422         2.421       18.770
# 799                8.568              -4.970         0.543        1.368
# 874               -5.351              -6.578         2.399       19.563
# 994              -10.145              -7.774         0.558        1.495
# 1069               2.675              14.419         2.382       21.134
# 1189               1.263             -11.031         0.574        1.636
# 1264              15.639               9.038         2.353       22.963
# 1384              12.406              -2.979         0.591        1.820
# 1459               2.711               5.030         2.321       24.979
# 1579              12.516               1.644         0.602        2.026
# 1654              11.865               3.980         2.299       27.589
# 1774               6.556              34.421         0.613        2.224
# 1849              20.656              13.752         2.277       30.740
# 1969              48.742              31.007         0.624        2.446
# 2044              17.055              23.505         2.250       35.097
# 2164             -14.183              35.333         0.635        2.700
# 2239              21.879               7.542         2.228       40.493
# 2359               9.603              67.032         0.643        3.129
# 2434              17.446              13.860         2.209       45.750
# 2554              19.982               9.320         0.651        3.539
# 2629             -11.140               2.319         2.192       45.088
# 2749             -16.627             -19.114         0.659        3.773
# 2824             -30.894             -12.874         2.163       38.954
# 2944              30.544              -0.018         0.667        4.179
# 3019              12.806              13.444         2.121       37.671
# 3261               9.722              12.116        20.199      360.566
# 3275              -1.358              35.311         0.538        1.125
# 3456              -1.816               1.105        20.096      378.487
# 3470               4.666              22.943         0.550        1.168
# 3651               9.088              20.578        20.020      395.318
# 3665              11.748               5.013         0.562        1.252
# 3846               8.840               8.536        19.953      411.273
# 3860              -2.400               3.367         0.575        1.288
# 3958               1.963               0.392         5.472      232.930
# 4041               8.508               4.583        19.876      428.249
# 4055               6.082               2.841         0.588        1.319
#
#        imports_gns  ...  co2_emissions_capita  forest_area  population_y  \
# 19    1.545732e+08  ...              0.430205    64.230151      534629.0
# 214   1.888924e+08  ...              0.517110    64.479598      541471.0
# 409   2.260895e+08  ...              0.670639    64.729045      551713.0
# 484   5.914903e+09  ...              3.506174    51.781465     2432851.0
# 604   2.835711e+08  ...              0.637870    64.978492      564378.0
# 679   6.906688e+09  ...              3.373417    51.890797     2410019.0
# 799   3.375256e+08  ...              0.622960    65.227940      577886.0
# 874   6.547208e+09  ...              3.158359    52.000129     2390482.0
# 994   3.516021e+08  ...              0.626043    65.477387      591014.0
# 1069  6.722315e+09  ...              2.927077    52.109460     2367550.0
# 1189  3.829480e+08  ...              0.596379    65.726859      603643.0
# 1264  7.773639e+09  ...              3.149108    52.320278     2337170.0
# 1384  4.483506e+08  ...              0.649324    65.976332      616025.0
# 1459  7.984376e+09  ...              3.181580    52.531095     2310173.0
# 1579  5.022359e+08  ...              0.573394    66.225804      627840.0
# 1654  8.931736e+09  ...              3.317373    52.741913     2287955.0
# 1774  6.454854e+08  ...              0.485278    69.410394      638809.0
# 1849  1.077665e+10  ...              3.367030    52.952730     2263122.0
# 1969  7.293070e+08  ...              0.631990    69.670882      648744.0
# 2044  1.261464e+10  ...              3.448277    53.163547     2238799.0
# 2164  7.138805e+08  ...              0.608454    69.931369      657404.0
# 2239  1.537454e+10  ...              3.696429    53.374365     2218357.0
# 2359  7.921541e+08  ...              0.586578    70.191857      664873.0
# 2434  1.805680e+10  ...              3.876700    53.585182     2200325.0
# 2554  8.139471e+08  ...              0.595583    70.452344      671611.0
# 2629  1.604533e+10  ...              3.724759    53.796000     2177322.0
# 2749  9.307128e+08  ...              0.545458    70.712832      678329.0
# 2824  1.108822e+10  ...              3.436572    54.020714     2141669.0
# 2944  1.198164e+09  ...              0.685629    70.973319      685502.0
# 3019  1.250817e+10  ...              4.061872    54.179306     2097555.0
# 3261  5.930455e+10  ...              4.166764    28.640535    20147528.0
# 3275  4.944086e+08  ...              0.646326    90.373276      541522.0
# 3456  5.822749e+10  ...              4.074676    28.994800    20058035.0
# 3470  4.981275e+08  ...              0.647405    90.347124      556066.0
# 3651  6.351929e+10  ...              3.603438    29.329114    19983693.0
# 3665  5.525305e+08  ...              0.682619    90.320972      571329.0
# 3846  6.913417e+10  ...              3.586824    29.658241    19908979.0
# 3860  5.439238e+08  ...              0.579138    90.294820      587079.0
# 3958  8.434120e+10  ...              7.814537    73.735645     5479531.0
# 4041  7.501600e+10  ...              3.678917    29.993741    19815616.0
# 4055  6.180904e+08  ...              0.513983    90.268667      603133.0
#
#       ghg_total  ghg_growth  ghg_capita  mean_surface_temp  log_ghg_capita  \
# 19       1270.0       -1.82       -9.95              0.431             NaN
# 214      1300.0       -0.62       -9.76              0.204             NaN
# 409      1390.0       -1.66       -9.42             -0.358             NaN
# 484     12430.0     -451.33       -0.18              0.750             NaN
# 604      1390.0       -0.26       -9.19              0.758             NaN
# 679     11980.0      100.15       -0.36              0.643             NaN
# 799      1430.0       -1.13       -8.87              0.954             NaN
# 874     11270.0       73.85       -0.64              1.545             NaN
# 994      1410.0        1.05       -8.77              0.126             NaN
# 1069    10490.0       45.43       -0.93              2.004             NaN
# 1189     1350.0        1.21       -8.69              0.655             NaN
# 1264    11020.0       30.07       -1.23              1.814             NaN
# 1384     1390.0       -0.59       -8.46              0.458             NaN
# 1459    11060.0       -1.52       -1.22              1.716             NaN
# 1579     1360.0        0.63       -8.36              0.502             NaN
# 1654    11170.0       -4.85       -1.18              0.242             NaN
# 1774     1320.0        0.58       -8.26              0.478             NaN
# 1849    11250.0       -3.31       -1.15              1.014             NaN
# 1969     1510.0       -3.50       -7.85              0.759             NaN
# 2044    11410.0       -6.09       -1.09              1.343             NaN
# 2164     1490.0        0.34       -7.77              0.993             NaN
# 2239    11940.0      -22.06       -0.86              1.071             NaN
# 2359     1510.0       -1.57       -7.56              0.987             NaN
# 2434    12360.0      -22.35       -0.67              2.189             NaN
# 2554     1440.0        2.60       -7.68              0.588             NaN
# 2629    12010.0       21.85       -0.83              2.388             NaN
# 2749     1470.0       -0.45       -7.57              1.424             NaN
# 2824    11220.0       43.85       -1.21              1.502             NaN
# 2944     1570.0       -2.84       -7.28              1.196             NaN
# 3019    12390.0      -45.72       -0.67              0.676             NaN
# 3261   119570.0     -247.55       -8.22              0.503             NaN
# 3275      780.0     -797.57      -31.48              0.089             NaN
# 3456   116870.0        1.64       -8.39              1.830             NaN
# 3470      800.0       -0.10      -30.62              0.038             NaN
# 3651   107300.0        5.69       -8.90              1.384             NaN
# 3665      850.0       -0.30      -29.71              0.582             NaN
# 3846   106410.0        0.50       -8.98              1.576             NaN
# 3860      820.0        0.17      -28.97              0.642             NaN
# 3958    53550.0     -145.15       -0.20              2.629             NaN
# 4041   108090.0       -0.93       -8.93              1.854             NaN
# 4055      800.0        0.11      -28.23              0.422             NaN
#
#       log_gdp_capita  log_gdp_capita_sq
# 19          8.115425          65.860127
# 214         8.165597          66.676970
# 409         8.204081          67.306948
# 484         9.286767          86.244042
# 604         8.237786          67.861120
# 679         9.358161          87.575178
# 799         8.278553          68.534434
# 874         9.394141          88.249882
# 994         8.318640          69.199768
# 1069        9.456645          89.428131
# 1189        8.356973          69.838994
# 1264        9.529921          90.819403
# 1384        8.419029          70.880048
# 1459        9.612228          92.394935
# 1579        8.490297          72.085138
# 1654        9.702540          94.139275
# 1774        8.538959          72.913814
# 1849        9.794127          95.924931
# 1969        8.585650          73.713380
# 2044        9.907848          98.165453
# 2164        8.636749          74.593431
# 2239       10.030815         100.617243
# 2359        8.745480          76.483426
# 2434       10.134951         102.717236
# 2554        8.837262          78.097193
# 2629       10.108852         102.188889
# 2749        8.881395          78.879169
# 2824        9.968313          99.367259
# 2944        8.959754          80.277186
# 3019        9.943010          98.863441
# 3261        9.945460          98.912179
# 3275        7.738715          59.887705
# 3456        9.970779          99.416431
# 3470        7.735857          59.843487
# 3651       10.011579         100.231712
# 3665        7.765484          60.302746
# 3846       10.050383         101.010192
# 3860        7.753190          60.111955
# 3958       10.717636         114.867729
# 4041       10.083388         101.674719
# 4055        7.745501          59.992778
#
# [41 rows x 22 columns]

# %%
# Perform PooledOLS
data['year'] = pd.to_datetime(data['year'], format='%Y')
# #add column year to index
data = data.set_index('year', append=True)

# %%
#exog = sm.tools.tools.add_constant(data["log_gdp_capita"])
exog = sm.tools.tools.add_constant(data.filter(["log_gdp_capita", "log_gdp_capita_sq", "vol_exports_change", "vol_imports_change", "mean_surface_temp"], axis = 1))
endog = data["log_ghg_capita"]
mod = PooledOLS(endog, exog)
pooledOLS_res = mod.fit(cov_type='clustered', cluster_entity=True)
# Store values for checking homoskedasticity graphically
fittedvals_pooled_OLS = pooledOLS_res.predict().fitted_values
residuals_pooled_OLS = pooledOLS_res.resids
# Out:
# /home/kaveri/.local/lib/python3.8/site-packages/linearmodels/shared/exceptions.py:37: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)

# %%
print(pooledOLS_res)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.4837
# Estimator:                  PooledOLS   R-squared (Between):              0.4837
# No. Observations:                2668   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.4837
# Time:                        00:56:44   Log-likelihood                   -2573.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      498.86
# Entities:                        2668   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                  F(5,2662)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             562.36
#                                         P-value                           0.0000
# Time periods:                      24   Distribution:                  F(5,2662)
# Avg Obs:                       111.17
# Min Obs:                       103.00
# Max Obs:                       114.00
#
#                                  Parameter Estimates
# ======================================================================================
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# const                  2.0860     0.7226     2.8868     0.0039      0.6691      3.5030
# log_gdp_capita        -0.6265     0.1589    -3.9416     0.0001     -0.9381     -0.3148
# log_gdp_capita_sq      0.0633     0.0086     7.3188     0.0000      0.0463      0.0802
# vol_exports_change  5.757e-05     0.0013     0.0440     0.9649     -0.0025      0.0026
# vol_imports_change    -0.0006     0.0013    -0.4518     0.6514     -0.0030      0.0019
# mean_surface_temp     -0.1532     0.0238    -6.4387     0.0000     -0.1998     -0.1065
# ======================================================================================

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(x = data['gdp_capita'], y = data['ghg_capita'])
plt.xlabel("GDP per capita")
plt.ylabel("GHG emissions per capita")
plt.show()

# %%
#QQPlot to check for normality
sm.qqplot(residuals_pooled_OLS, line='45')
plt.show()

# %% [markdown]
# The plot shows that the residuals of the plot are not normalaly distributed. Even though the residual errors are not normally distributed, the Pooled OLS estimator is still the Best Linear Unbiased Estimator (BLUE) for the panel data regression problem. Non-normality of residual errors does not affect the BLUE-ness of OLS regression model.

# %%
#  Homoskedasticity
# Residuals-Plot for growing Variance Detection
fig, ax = plt.subplots()
ax.scatter(fittedvals_pooled_OLS, residuals_pooled_OLS, color = 'blue')
ax.axhline(0, color = 'r', ls = '--')
ax.set_xlabel('Predicted Values', fontsize = 15)
ax.set_ylabel('Residuals', fontsize = 15)
ax.set_title('Homoskedasticity Test', fontsize = 30)
plt.show()

# %%
#check for autocorrelation
import statsmodels.graphics.tsaplots as tsap
tsap.plot_acf(x=residuals_pooled_OLS)
plt.show()

# %% [markdown]
# The perfect correlation of 1.0 at lag 0 is to be ignored as a number is always perfectly correlated with itself. But we see significant auto-correlation between residual errors at lags 1, 2 and 3.

# %% [markdown]
# # Fixed Effects Regression

# %%
data2 = combined_data.copy()
data2["log_ghg_capita"] = np.log(data2["ghg_capita"])
data2["log_gdp_capita"] = np.log(pd.to_numeric(data2["gdp_capita"]))
data2["log_gdp_capita_sq"] = (np.log(pd.to_numeric(data2["gdp_capita"])))**2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data2
# Out:
#                    country iso_code  year  gdp_constant_change  gdp_capita  \
# 1                  Albania      ALB  1995                8.900     4582.93
# 2                  Algeria      DZA  1995                3.848     8158.72
# 3                   Angola      AGO  1995               10.364     3973.12
# 5                Argentina      ARG  1995               -2.845    17387.03
# 6                  Armenia      ARM  1995                8.033     3008.39
# ...                    ...      ...   ...                  ...         ...
# 5058  United Arab Emirates      ARE  2020               -5.924    55693.97
# 5059        United Kingdom      GBR  2020               -9.920    41819.88
# 5060         United States      USA  2020               -3.505    60114.17
# 5062            Uzbekistan      UZB  2020                1.648     7061.48
# 5065               Vietnam      VNM  2020                2.906    10302.96
#
#       vol_imports_change  vol_exports_change  population_x  gdp_current  \
# 1                  0.000                 NaN         3.188        9.643
# 2                  2.000               5.733        28.060      204.348
# 3                 27.968              12.240        14.771       37.582
# 5                -11.484              25.559        34.779      347.223
# 6                    NaN                 NaN         3.220        5.862
# ...                  ...                 ...           ...          ...
# 5058             -18.151             -13.652        11.077      650.829
# 5059             -18.127             -16.721        67.093     2959.920
# 5060              -9.285             -12.970       330.086    20932.750
# 5062             -13.564             -17.914        33.906      252.576
# 5065               2.948               2.822        97.406     1058.690
#
#        imports_gns  ...  co2_emissions_capita  forest_area  population_y  \
# 1              NaN  ...              0.611710    28.432482     3187784.0
# 2     1.659053e+10  ...              2.540181     0.681435    28757788.0
# 3              NaN  ...              0.773026    62.954757    13945205.0
# 5     2.737656e+10  ...              3.267757    12.530100    34828168.0
# 6     2.493916e+09  ...              1.090960    11.720583     3217349.0
# ...            ...  ...                   ...          ...           ...
# 5058           NaN  ...                   NaN          NaN           NaN
# 5059  8.073590e+11  ...                   NaN          NaN           NaN
# 5060  2.839770e+12  ...                   NaN          NaN           NaN
# 5062  2.251167e+10  ...                   NaN          NaN           NaN
# 5065  2.973920e+11  ...                   NaN          NaN           NaN
#
#       ghg_total  ghg_growth  ghg_capita  mean_surface_temp  log_ghg_capita  \
# 1        7430.0       -3.06        2.39             -0.127        0.871293
# 2      103000.0        4.23        3.60              0.619        1.280934
# 3       48460.0        6.50        5.12              0.827        1.633154
# 5      260580.0        0.19        8.78              0.210        2.172476
# 6        6710.0        9.73        2.13              0.730        0.756122
# ...         ...         ...         ...                ...             ...
# 5058        NaN         NaN         NaN                NaN             NaN
# 5059        NaN         NaN         NaN                NaN             NaN
# 5060        NaN         NaN         NaN                NaN             NaN
# 5062        NaN         NaN         NaN                NaN             NaN
# 5065        NaN         NaN         NaN                NaN             NaN
#
#       log_gdp_capita  log_gdp_capita_sq
# 1           8.430094          71.066482
# 2           9.006843          81.123213
# 3           8.287307          68.679457
# 5           9.763480          95.325538
# 6           8.009160          64.146649
# ...              ...                ...
# 5058       10.927627         119.413035
# 5059       10.641127         113.233586
# 5060       11.004001         121.088035
# 5062        8.862410          78.542310
# 5065        9.240187          85.381047
#
# [2964 rows x 22 columns]

# %%
data2.head()
# Out:
#      country iso_code  year  gdp_constant_change  gdp_capita  \
# 1    Albania      ALB  1995                8.900     4582.93
# 2    Algeria      DZA  1995                3.848     8158.72
# 3     Angola      AGO  1995               10.364     3973.12
# 5  Argentina      ARG  1995               -2.845    17387.03
# 6    Armenia      ARM  1995                8.033     3008.39
#
#    vol_imports_change  vol_exports_change  population_x  gdp_current  \
# 1               0.000                 NaN         3.188        9.643
# 2               2.000               5.733        28.060      204.348
# 3              27.968              12.240        14.771       37.582
# 5             -11.484              25.559        34.779      347.223
# 6                 NaN                 NaN         3.220        5.862
#
#     imports_gns  ...  co2_emissions_capita  forest_area  population_y  \
# 1           NaN  ...              0.611710    28.432482     3187784.0
# 2  1.659053e+10  ...              2.540181     0.681435    28757788.0
# 3           NaN  ...              0.773026    62.954757    13945205.0
# 5  2.737656e+10  ...              3.267757    12.530100    34828168.0
# 6  2.493916e+09  ...              1.090960    11.720583     3217349.0
#
#    ghg_total  ghg_growth  ghg_capita  mean_surface_temp  log_ghg_capita  \
# 1     7430.0       -3.06        2.39             -0.127        0.871293
# 2   103000.0        4.23        3.60              0.619        1.280934
# 3    48460.0        6.50        5.12              0.827        1.633154
# 5   260580.0        0.19        8.78              0.210        2.172476
# 6     6710.0        9.73        2.13              0.730        0.756122
#
#    log_gdp_capita  log_gdp_capita_sq
# 1        8.430094          71.066482
# 2        9.006843          81.123213
# 3        8.287307          68.679457
# 5        9.763480          95.325538
# 6        8.009160          64.146649
#
# [5 rows x 22 columns]

# %%
#Imputing missing data using KNNImputer for the entire column
# from sklearn.impute import KNNImputer
# imputer = KNNImputer(n_neighbors=2, weights="uniform")
# X = data2.iloc[:,3:]
# X = imputer.fit_transform(X)
# X
# X.shape

# %%
# data2["iso_code"].unique()
# data2[data2["iso_code"] == "AFG"].iloc[:,3:]

# %%
# for country in data2["iso_code"].unique():
#     df = data2[data2["iso_code"] == country]
#     imputer = KNNImputer(n_neighbors=2)
#     X = df.iloc[:,3:]
#     out = imputer.fit_transform(X)

# %%
# Imputing missing data grouped by countries

def impute_missing_values(df):
    imputer = KNNImputer(n_neighbors=2)
    X = df.iloc[:,3:]
    out = imputer.fit_transform(X)
    out1 = pd.DataFrame(out, columns = df.columns[3:])
    # print("length of the output",X.shape[1])
    # print("len of output", len(out[1]) )
    # if X.shape[1] == len(out[1]): # we should have the same
    return out1

res = data2.groupby(["iso_code", "country"], as_index = False).apply(impute_missing_values)

# %%
res.iloc[:,1:]
res.reset_index(drop=True, inplace=True)
res
# Out:
#       gdp_constant_change  gdp_capita  vol_imports_change  vol_exports_change  \
# 0                  10.364     3973.12              27.968              12.240
# 1                  11.208     4289.72              27.764              10.698
# 2                   7.274     4467.73               8.432               6.020
# 3                   4.691     4541.09              -5.440               2.536
# 4                   2.181     4505.00              26.806               1.426
# ...                   ...         ...                 ...                 ...
# 2959                0.399    12692.90              -3.861               0.352
# 2960                1.415    12681.72               0.970              -0.729
# 2961                0.787    12596.00               3.296               2.638
# 2962                0.153    12435.79              -0.486              -2.511
# 2963               -6.960    11405.93             -16.615             -10.280
#
#       population_x  gdp_current   imports_gns   exports_gns  co2_emissions_kt  \
# 0           14.771       37.582  1.210154e+10  1.528519e+10           10780.0
# 1           15.214       42.559  1.210154e+10  1.528519e+10           11410.0
# 2           15.671       46.442  1.210154e+10  1.528519e+10           11730.0
# 3           16.141       49.168  1.210154e+10  1.528519e+10           11370.0
# 4           16.625       50.966  1.210154e+10  1.528519e+10           12650.0
# ...            ...          ...           ...           ...               ...
# 2959        56.252      707.744  9.643336e+10  9.647746e+10          425180.0
# 2960        57.098      724.101  9.791114e+10  9.621385e+10          435140.0
# 2961        57.939      747.322  1.010880e+11  9.891633e+10          433250.0
# 2962        58.775      761.824  1.015670e+11  9.554470e+10          429065.0
# 2963        59.622      717.396  8.387063e+10  8.412670e+10          417115.0
#
#       co2_emissions_capita  forest_area  population_y  ghg_total  ghg_growth  \
# 0                 0.773026    62.954757    13945205.0    48460.0       6.500
# 1                 0.792321    62.830094    14400722.0    46480.0       2.610
# 2                 0.788753    62.705431    14871572.0    46680.0      -2.170
# 3                 0.740254    62.580768    15359600.0    49410.0      10.990
# 4                 0.797259    62.456106    15866871.0    48770.0      -2.490
# ...                    ...          ...           ...        ...         ...
# 2959              7.564451    14.175115    56207649.0   501550.0       0.150
# 2960              7.632729    14.145109    57009751.0   514600.0       2.580
# 2961              7.496645    14.115103    57792520.0   513440.0      -0.160
# 2962              7.583923    14.085097    58558267.0   507265.0      -2.340
# 2963              8.083651    14.340148    51610363.0   491985.0       0.815
#
#       ghg_capita  mean_surface_temp  log_ghg_capita  log_gdp_capita  \
# 0          5.120              0.827        1.633154        8.287307
# 1          5.090              0.455        1.627278        8.363977
# 2          4.820              0.300        1.572774        8.404636
# 3          5.180              1.206        1.644805        8.420922
# 4          4.890              0.499        1.587192        8.412943
# ...          ...                ...             ...             ...
# 2959       9.040              1.669        2.201659        9.448798
# 2960       9.150              1.151        2.213754        9.447917
# 2961       9.010              1.083        2.198335        9.441135
# 2962       9.085              1.826        2.206591        9.428334
# 2963       9.655              0.891        2.267204        9.341889
#
#       log_gdp_capita_sq
# 0             68.679457
# 1             69.956107
# 2             70.637902
# 3             70.911933
# 4             70.777613
# ...                 ...
# 2959          89.279785
# 2960          89.263133
# 2961          89.135022
# 2962          88.893480
# 2963          87.270884
#
# [2964 rows x 19 columns]

# %%
data2.iloc[:,:3]
data2.reset_index(drop=True, inplace=True)

# %%
frames = [data2.iloc[:,:3], res]
final_dataset = pd.concat(frames,  axis=1)

# %%
final_dataset
# Out:
#                    country iso_code  year  gdp_constant_change  gdp_capita  \
# 0                  Albania      ALB  1995               10.364     3973.12
# 1                  Algeria      DZA  1995               11.208     4289.72
# 2                   Angola      AGO  1995                7.274     4467.73
# 3                Argentina      ARG  1995                4.691     4541.09
# 4                  Armenia      ARM  1995                2.181     4505.00
# ...                    ...      ...   ...                  ...         ...
# 2959  United Arab Emirates      ARE  2020                0.399    12692.90
# 2960        United Kingdom      GBR  2020                1.415    12681.72
# 2961         United States      USA  2020                0.787    12596.00
# 2962            Uzbekistan      UZB  2020                0.153    12435.79
# 2963               Vietnam      VNM  2020               -6.960    11405.93
#
#       vol_imports_change  vol_exports_change  population_x  gdp_current  \
# 0                 27.968              12.240        14.771       37.582
# 1                 27.764              10.698        15.214       42.559
# 2                  8.432               6.020        15.671       46.442
# 3                 -5.440               2.536        16.141       49.168
# 4                 26.806               1.426        16.625       50.966
# ...                  ...                 ...           ...          ...
# 2959              -3.861               0.352        56.252      707.744
# 2960               0.970              -0.729        57.098      724.101
# 2961               3.296               2.638        57.939      747.322
# 2962              -0.486              -2.511        58.775      761.824
# 2963             -16.615             -10.280        59.622      717.396
#
#        imports_gns  ...  co2_emissions_capita  forest_area  population_y  \
# 0     1.210154e+10  ...              0.773026    62.954757    13945205.0
# 1     1.210154e+10  ...              0.792321    62.830094    14400722.0
# 2     1.210154e+10  ...              0.788753    62.705431    14871572.0
# 3     1.210154e+10  ...              0.740254    62.580768    15359600.0
# 4     1.210154e+10  ...              0.797259    62.456106    15866871.0
# ...            ...  ...                   ...          ...           ...
# 2959  9.643336e+10  ...              7.564451    14.175115    56207649.0
# 2960  9.791114e+10  ...              7.632729    14.145109    57009751.0
# 2961  1.010880e+11  ...              7.496645    14.115103    57792520.0
# 2962  1.015670e+11  ...              7.583923    14.085097    58558267.0
# 2963  8.387063e+10  ...              8.083651    14.340148    51610363.0
#
#       ghg_total  ghg_growth  ghg_capita  mean_surface_temp  log_ghg_capita  \
# 0       48460.0       6.500       5.120              0.827        1.633154
# 1       46480.0       2.610       5.090              0.455        1.627278
# 2       46680.0      -2.170       4.820              0.300        1.572774
# 3       49410.0      10.990       5.180              1.206        1.644805
# 4       48770.0      -2.490       4.890              0.499        1.587192
# ...         ...         ...         ...                ...             ...
# 2959   501550.0       0.150       9.040              1.669        2.201659
# 2960   514600.0       2.580       9.150              1.151        2.213754
# 2961   513440.0      -0.160       9.010              1.083        2.198335
# 2962   507265.0      -2.340       9.085              1.826        2.206591
# 2963   491985.0       0.815       9.655              0.891        2.267204
#
#       log_gdp_capita  log_gdp_capita_sq
# 0           8.287307          68.679457
# 1           8.363977          69.956107
# 2           8.404636          70.637902
# 3           8.420922          70.911933
# 4           8.412943          70.777613
# ...              ...                ...
# 2959        9.448798          89.279785
# 2960        9.447917          89.263133
# 2961        9.441135          89.135022
# 2962        9.428334          88.893480
# 2963        9.341889          87.270884
#
# [2964 rows x 22 columns]

# %%
# exog_vars = ["log_gdp_capita", "log_gdp_capita_sq"] + np.unique(final_dataset.year)[1::].tolist()
# final_dataset['year'] = pd.to_datetime(final_dataset['year'], format='%Y')
# final_dataset = final_dataset.set_index('year', append=True)
# exog = sm.tools.tools.add_constant(final_dataset.filter(exog_vars, axis = 1))
# endog = final_dataset["log_ghg_capita"]

# %%
# from linearmodels.panel import compare
# #fixed effects regression
# # df["year"] = final_dataset["year"]
# mod_fe = PanelOLS(endog, exog)
# fe_res = mod_fe.fit()
# print(fe_res.tables())

# %%
region_mapping[region_mapping["country"]=="India"]
# Out:
#     country iso_code region     sub_region intermediate_region
# 103   India      IND   Asia  Southern Asia

# %%
final_data2 = pd.merge(final_dataset, region_mapping, on = [ "iso_code",], how = "left")
final_data2
# Out:
#                  country_x iso_code  year  gdp_constant_change  gdp_capita  \
# 0                  Albania      ALB  1995               10.364     3973.12
# 1                  Algeria      DZA  1995               11.208     4289.72
# 2                   Angola      AGO  1995                7.274     4467.73
# 3                Argentina      ARG  1995                4.691     4541.09
# 4                  Armenia      ARM  1995                2.181     4505.00
# ...                    ...      ...   ...                  ...         ...
# 2959  United Arab Emirates      ARE  2020                0.399    12692.90
# 2960        United Kingdom      GBR  2020                1.415    12681.72
# 2961         United States      USA  2020                0.787    12596.00
# 2962            Uzbekistan      UZB  2020                0.153    12435.79
# 2963               Vietnam      VNM  2020               -6.960    11405.93
#
#       vol_imports_change  vol_exports_change  population_x  gdp_current  \
# 0                 27.968              12.240        14.771       37.582
# 1                 27.764              10.698        15.214       42.559
# 2                  8.432               6.020        15.671       46.442
# 3                 -5.440               2.536        16.141       49.168
# 4                 26.806               1.426        16.625       50.966
# ...                  ...                 ...           ...          ...
# 2959              -3.861               0.352        56.252      707.744
# 2960               0.970              -0.729        57.098      724.101
# 2961               3.296               2.638        57.939      747.322
# 2962              -0.486              -2.511        58.775      761.824
# 2963             -16.615             -10.280        59.622      717.396
#
#        imports_gns  ...  ghg_growth  ghg_capita  mean_surface_temp  \
# 0     1.210154e+10  ...       6.500       5.120              0.827
# 1     1.210154e+10  ...       2.610       5.090              0.455
# 2     1.210154e+10  ...      -2.170       4.820              0.300
# 3     1.210154e+10  ...      10.990       5.180              1.206
# 4     1.210154e+10  ...      -2.490       4.890              0.499
# ...            ...  ...         ...         ...                ...
# 2959  9.643336e+10  ...       0.150       9.040              1.669
# 2960  9.791114e+10  ...       2.580       9.150              1.151
# 2961  1.010880e+11  ...      -0.160       9.010              1.083
# 2962  1.015670e+11  ...      -2.340       9.085              1.826
# 2963  8.387063e+10  ...       0.815       9.655              0.891
#
#       log_ghg_capita  log_gdp_capita  log_gdp_capita_sq  \
# 0           1.633154        8.287307          68.679457
# 1           1.627278        8.363977          69.956107
# 2           1.572774        8.404636          70.637902
# 3           1.644805        8.420922          70.911933
# 4           1.587192        8.412943          70.777613
# ...              ...             ...                ...
# 2959        2.201659        9.448798          89.279785
# 2960        2.213754        9.447917          89.263133
# 2961        2.198335        9.441135          89.135022
# 2962        2.206591        9.428334          88.893480
# 2963        2.267204        9.341889          87.270884
#
#                                               country_y    region  \
# 0                                               Albania    Europe
# 1                                               Algeria    Africa
# 2                                                Angola    Africa
# 3                                             Argentina  Americas
# 4                                               Armenia      Asia
# ...                                                 ...       ...
# 2959                               United Arab Emirates      Asia
# 2960  United Kingdom of Great Britain and Northern I...    Europe
# 2961                           United States of America  Americas
# 2962                                         Uzbekistan      Asia
# 2963                                           Viet Nam      Asia
#
#                            sub_region  intermediate_region
# 0                     Southern Europe
# 1                     Northern Africa
# 2                  Sub-Saharan Africa        Middle Africa
# 3     Latin America and the Caribbean        South America
# 4                        Western Asia
# ...                               ...                  ...
# 2959                     Western Asia
# 2960                  Northern Europe
# 2961                 Northern America
# 2962                     Central Asia
# 2963               South-eastern Asia
#
# [2964 rows x 26 columns]

# %%
# region
asia_data = final_data2[final_data2["region"] == "Asia"]
africa_data = final_data2[final_data2["region"] == "Africa"]
europe_data = final_data2[final_data2["region"] == "Europe"]
americas_data = final_data2[final_data2["region"] == "Americas"]

# %%
#sub-region analysis
eastern_asia = final_data2[final_data2["sub_region"] == "Eastern Asia"]
south_eastern_asia = final_data2[final_data2["sub_region"] == "South-eastern Asia"]
central_asia = final_data2[final_data2["sub_region"] == "Central Asia"]
western_asia = final_data2[final_data2["sub_region"] == "Western Asia"]
northern_america = final_data2[final_data2["sub_region"] == "Northern America"]
latin_america = final_data2[final_data2["sub_region"] == "Latin America and the Caribbean"]

# %%
def fixed_effects_model(dataset, explanatory_variable = None):
    vars = ["log_gdp_capita", "log_gdp_capita_sq"]
    exog_vars = vars + np.unique(dataset.year)[1::].tolist()
    dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')
    dataset = dataset.set_index('year', append=True)
    exog = sm.tools.tools.add_constant(dataset.filter(exog_vars, axis = 1))
    endog = dataset["log_ghg_capita"]
    mod_fe = PanelOLS(endog, exog, time_effects=True)
    fe_res = mod_fe.fit()
    print(fe_res)

# %%
fixed_effects_model(asia_data)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.4638
# Estimator:                   PanelOLS   R-squared (Between):              0.4064
# No. Observations:                 702   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.4064
# Time:                        01:08:53   Log-likelihood                   -645.13
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      291.54
# Entities:                         702   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(2,674)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             291.54
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(2,674)
# Avg Obs:                       27.000
# Min Obs:                       27.000
# Max Obs:                       27.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 6.5081     1.5922     4.0873     0.0000      3.3817      9.6344
# log_gdp_capita       -1.6349     0.3471    -4.7097     0.0000     -2.3165     -0.9533
# log_gdp_capita_sq     0.1177     0.0187     6.2850     0.0000      0.0810      0.1545
# =====================================================================================
#
# F-test for Poolability: 7.3253
# P-value: 0.0000
# Distribution: F(25,674)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
def fixed_effects_model2(dataset, explanatory_variable = None):
    vars = ["gdp_capita"]
    exog_vars = vars + np.unique(dataset.year)[1::].tolist()
    dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')
    dataset = dataset.set_index('year', append=True)
    exog = sm.tools.tools.add_constant(dataset.filter(exog_vars, axis = 1))
    endog = dataset["ghg_capita"]
    mod_fe = PanelOLS(endog, exog, time_effects=True)
    fe_res = mod_fe.fit()
    print(fe_res)

# %%
fixed_effects_model2(asia_data)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:             ghg_capita   R-squared:                        0.3726
# Estimator:                   PanelOLS   R-squared (Between):              0.3090
# No. Observations:                 702   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.3090
# Time:                        01:08:38   Log-likelihood                   -2255.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      400.81
# Entities:                         702   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(1,675)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             400.81
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(1,675)
# Avg Obs:                       27.000
# Min Obs:                       27.000
# Max Obs:                       27.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          2.3077     0.3507     6.5810     0.0000      1.6192      2.9962
# gdp_capita     0.0003  1.262e-05     20.020     0.0000      0.0002      0.0003
# ==============================================================================
#
# F-test for Poolability: 10.137
# P-value: 0.0000
# Distribution: F(25,675)
#
# Included effects: Time
# <ipython-input-254-7b17044aa47a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(africa_data)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.4481
# Estimator:                   PanelOLS   R-squared (Between):              0.4190
# No. Observations:                 728   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.4190
# Time:                        01:11:01   Log-likelihood                   -668.50
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      284.19
# Entities:                         728   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(2,700)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             284.19
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(2,700)
# Avg Obs:                       28.000
# Min Obs:                       28.000
# Max Obs:                       28.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 4.4959     1.5369     2.9252     0.0036      1.4783      7.5134
# log_gdp_capita       -1.1598     0.3367    -3.4446     0.0006     -1.8208     -0.4987
# log_gdp_capita_sq     0.0907     0.0182     4.9767     0.0000      0.0549      0.1265
# =====================================================================================
#
# F-test for Poolability: 7.8295
# P-value: 0.0000
# Distribution: F(25,700)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(americas_data)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.4991
# Estimator:                   PanelOLS   R-squared (Between):              0.5305
# No. Observations:                 520   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.5305
# Time:                        01:11:14   Log-likelihood                   -410.98
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      245.11
# Entities:                         520   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(2,492)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             245.11
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(2,492)
# Avg Obs:                       20.000
# Min Obs:                       20.000
# Max Obs:                       20.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 3.3194     1.7470     1.9001     0.0580     -0.1130      6.7518
# log_gdp_capita       -0.9418     0.3789    -2.4858     0.0133     -1.6861     -0.1974
# log_gdp_capita_sq     0.0803     0.0203     3.9495     0.0001      0.0403      0.1202
# =====================================================================================
#
# F-test for Poolability: 6.8932
# P-value: 0.0000
# Distribution: F(25,492)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(europe_data)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.4248
# Estimator:                   PanelOLS   R-squared (Between):              0.3993
# No. Observations:                 936   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.3993
# Time:                        01:11:33   Log-likelihood                   -936.97
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      335.30
# Entities:                         936   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(2,908)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             335.30
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(2,908)
# Avg Obs:                       36.000
# Min Obs:                       36.000
# Max Obs:                       36.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 5.5981     1.4821     3.7772     0.0002      2.6894      8.5067
# log_gdp_capita       -1.4380     0.3242    -4.4353     0.0000     -2.0743     -0.8017
# log_gdp_capita_sq     0.1072     0.0175     6.1123     0.0000      0.0728      0.1416
# =====================================================================================
#
# F-test for Poolability: 8.7968
# P-value: 0.0000
# Distribution: F(25,908)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(eastern_asia)
# Out:
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')
# ---------------------------------------------------------------------------
# AbsorbingEffectError                      Traceback (most recent call last)
# <ipython-input-262-adf2c79f535d> in <module>
# ----> 1 fixed_effects_model(eastern_asia)
#
# <ipython-input-256-afce273b6731> in fixed_effects_model(dataset, explanatory_variable)
#       7     endog = dataset["log_ghg_capita"]
#       8     mod_fe = PanelOLS(endog, exog, time_effects=True)
# ----> 9     fe_res = mod_fe.fit()
#      10     print(fe_res)
#
# ~/.local/lib/python3.8/site-packages/linearmodels/panel/model.py in fit(self, use_lsdv, use_lsmr, low_memory, cov_type, debiased, auto_df, count_effects, **cov_config)
#    1814         if self.entity_effects or self.time_effects or self.other_effects:
#    1815             if not self._drop_absorbed:
# -> 1816                 check_absorbed(x, [str(var) for var in self.exog.vars])
#    1817             else:
#    1818                 # TODO: Need to special case the constant here when determining which to retain
#
# ~/.local/lib/python3.8/site-packages/linearmodels/panel/utility.py in check_absorbed(x, variables, x_orig)
#     444         absorbed_variables = "\n".join(rows)
#     445         msg = absorbing_error_msg.format(absorbed_variables=absorbed_variables)
# --> 446         raise AbsorbingEffectError(msg)
#     447     if x_orig is None:
#     448         return
#
# AbsorbingEffectError:
# The model cannot be estimated. The included effects have fully absorbed
# one or more of the variables. This occurs when one or more of the dependent
# variable is perfectly explained using the effects included in the model.
#
# The following variables or variable combinations have been fully absorbed
# or have become perfectly collinear after effects are removed:
#
#           const, log_gdp_capita, log_gdp_capita_sq
#           const, log_gdp_capita, log_gdp_capita_sq
#
# Set drop_absorbed=True to automatically drop absorbed variables.

# %%
fixed_effects_model(south_eastern_asia)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.4422
# Estimator:                   PanelOLS   R-squared (Between):              0.4003
# No. Observations:                 208   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.4003
# Time:                        01:11:59   Log-likelihood                   -180.18
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      71.357
# Entities:                         208   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(2,180)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             71.357
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(2,180)
# Avg Obs:                       8.0000
# Min Obs:                       8.0000
# Max Obs:                       8.0000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 2.2394     2.9136     0.7686     0.4431     -3.5098      7.9886
# log_gdp_capita       -0.6541     0.6360    -1.0285     0.3051     -1.9091      0.6008
# log_gdp_capita_sq     0.0629     0.0344     1.8322     0.0686     -0.0048      0.1307
# =====================================================================================
#
# F-test for Poolability: 2.9328
# P-value: 0.0000
# Distribution: F(25,180)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(south_eastern_asia)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.4422
# Estimator:                   PanelOLS   R-squared (Between):              0.4003
# No. Observations:                 208   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.4003
# Time:                        01:12:20   Log-likelihood                   -180.18
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      71.357
# Entities:                         208   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(2,180)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             71.357
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(2,180)
# Avg Obs:                       8.0000
# Min Obs:                       8.0000
# Max Obs:                       8.0000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 2.2394     2.9136     0.7686     0.4431     -3.5098      7.9886
# log_gdp_capita       -0.6541     0.6360    -1.0285     0.3051     -1.9091      0.6008
# log_gdp_capita_sq     0.0629     0.0344     1.8322     0.0686     -0.0048      0.1307
# =====================================================================================
#
# F-test for Poolability: 2.9328
# P-value: 0.0000
# Distribution: F(25,180)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(central_asia)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.6420
# Estimator:                   PanelOLS   R-squared (Between):              0.4845
# No. Observations:                  78   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.4845
# Time:                        01:12:27   Log-likelihood                   -34.301
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      44.826
# Entities:                          78   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                    F(2,50)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             44.826
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                    F(2,50)
# Avg Obs:                       3.0000
# Min Obs:                       3.0000
# Max Obs:                       3.0000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 11.505     5.4586     2.1078     0.0401      0.5417      22.469
# log_gdp_capita       -2.8909     1.1855    -2.4385     0.0183     -5.2721     -0.5097
# log_gdp_capita_sq     0.1932     0.0638     3.0303     0.0039      0.0651      0.3213
# =====================================================================================
#
# F-test for Poolability: 2.9288
# P-value: 0.0006
# Distribution: F(25,50)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(western_asia)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.5313
# Estimator:                   PanelOLS   R-squared (Between):              0.4474
# No. Observations:                 260   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.4474
# Time:                        01:12:37   Log-likelihood                   -214.05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      131.47
# Entities:                         260   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(2,232)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             131.47
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(2,232)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 6.7437     2.4820     2.7170     0.0071      1.8535      11.634
# log_gdp_capita       -1.7036     0.5422    -3.1419     0.0019     -2.7719     -0.6353
# log_gdp_capita_sq     0.1223     0.0293     4.1737     0.0000      0.0646      0.1800
# =====================================================================================
#
# F-test for Poolability: 3.2405
# P-value: 0.0000
# Distribution: F(25,232)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(northern_america)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.6104
# Estimator:                   PanelOLS   R-squared (Between):              0.5955
# No. Observations:                  52   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.5955
# Time:                        01:12:48   Log-likelihood                   -22.010
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      18.798
# Entities:                          52   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                    F(2,24)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             18.798
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                    F(2,24)
# Avg Obs:                       2.0000
# Min Obs:                       2.0000
# Max Obs:                       2.0000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 4.1926     6.5932     0.6359     0.5309     -9.4150      17.800
# log_gdp_capita       -1.1384     1.4554    -0.7822     0.4418     -4.1421      1.8653
# log_gdp_capita_sq     0.0905     0.0793     1.1410     0.2651     -0.0732      0.2543
# =====================================================================================
#
# F-test for Poolability: 1.2881
# P-value: 0.2690
# Distribution: F(25,24)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')

# %%
fixed_effects_model(latin_america)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         log_ghg_capita   R-squared:                        0.4885
# Estimator:                   PanelOLS   R-squared (Between):              0.5223
# No. Observations:                 468   R-squared (Within):               0.0000
# Date:                Mon, Mar 14 2022   R-squared (Overall):              0.5223
# Time:                        01:12:57   Log-likelihood                   -374.49
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      210.11
# Entities:                         468   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                   F(2,440)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             210.11
#                                         P-value                           0.0000
# Time periods:                      26   Distribution:                   F(2,440)
# Avg Obs:                       18.000
# Min Obs:                       18.000
# Max Obs:                       18.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                 3.5196     1.8842     1.8680     0.0624     -0.1835      7.2228
# log_gdp_capita       -0.9802     0.4077    -2.4042     0.0166     -1.7814     -0.1789
# log_gdp_capita_sq     0.0821     0.0218     3.7633     0.0002      0.0392      0.1250
# =====================================================================================
#
# F-test for Poolability: 6.0956
# P-value: 0.0000
# Distribution: F(25,440)
#
# Included effects: Time
# <ipython-input-256-afce273b6731>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['year'] = pd.to_datetime(dataset['year'], format='%Y')
